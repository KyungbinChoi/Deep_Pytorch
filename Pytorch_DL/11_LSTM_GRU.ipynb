# %%
import pandas as pd
import pandas_datareader.data as pdr
import yfinance as yf
yf.pdr_override()
import datetime
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import numpy as np
import argparse
from copy import deepcopy # Add Deepcopy for args
from sklearn.metrics import mean_absolute_error

import seaborn as sns 
import matplotlib
import matplotlib.pyplot as plt

print(torch.__version__)
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (15, 9)
# Out:
# 1.13.0

# %%
start = (2019, 12, 1)
start = datetime.datetime(*start)
end = datetime.date.today()
data = pdr.get_data_yahoo(["TSLA"], start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2019-12-02  21.959999  22.425333  21.912666  22.324667  22.324667   91117500
# 2019-12-03  22.174667  22.527332  22.146000  22.413334  22.413334   98605500
# 2019-12-04  22.516666  22.524000  22.190001  22.202000  22.202000   82995000
# 2019-12-05  22.188667  22.294666  21.816668  22.024668  22.024668   55869000
# 2019-12-06  22.333332  22.590668  22.318001  22.392668  22.392668  114186000

# %%
data.Low.plot(grid=True)
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
# many to one 으로 학습할 시 같은 가격대로 형성되어 학습이 잘 되지 않음 
# many to many 로 학습해 t+1,2,3,4 ... 의 기간을 예측하는 문제로 설정

# %%
class StockDataset(Dataset):
    def __init__(self, symbol, x_frames, y_frames, start, end) -> None:
        self.symbol = symbol
        self.x_frames = x_frames
        self.y_frames = y_frames
        self.start = datetime.datetime(*start)
        self.end = datetime.datetime(*end)

        self.data = pdr.get_data_yahoo([self.symbol], self.start, self.end)
        print('null count : ',self.data.isna().sum())

    def __len__(self):
        return len(self.data) - (self.x_frames + self.y_frames) + 1

    def __getitem__(self, index):
        index += self.x_frames
        data = self.data.iloc[index - self.x_frames:index+self.y_frames]
        data = data[['High','Low','Open', 'Close', 'Adj Close', 'Volume']]
        data = data.apply(lambda x:np.log(x+1) - np.log(x[self.x_frames-1]+1)) # scale normalization
        data = data.values
        X = data[:self.x_frames]
        y = data[self.x_frames:]

        return X, y

# %%
dataset = StockDataset('TSLA', 10, 5, (2019,1,1), (2022,12,1))
dataset[0]
# Out:
# [*********************100%***********************]  1 of 1 completed
# null count :  Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# (array([[-9.71176857e-02, -1.07747685e-01, -8.61804502e-02,
#          -1.00325062e-01, -1.00325062e-01,  6.54895513e-01],
#         [-1.14626878e-01, -1.12283167e-01, -8.33815307e-02,
#          -1.30804587e-01, -1.30804587e-01,  1.39777734e-01],
#         [-8.84616925e-02, -9.53016009e-02, -8.64919947e-02,
#          -7.73083405e-02, -7.73083405e-02,  1.99533796e-01],
#         [-3.37119566e-02, -4.91121118e-02, -3.86813776e-02,
#          -2.67005411e-02, -2.67005411e-02,  2.20557902e-01],
#         [-1.32539729e-02, -2.16343517e-02,  1.96906068e-02,
#          -2.55867884e-02, -2.55867884e-02,  1.45975110e-01],
#         [-1.46755727e-02, -8.70731263e-03,  1.42761193e-03,
#          -1.65511003e-02, -1.65511003e-02, -1.08675524e-01],
#         [-9.41747714e-03, -7.78412236e-03, -1.71571430e-03,
#           1.50122208e-03,  1.50122208e-03, -3.30223723e-05],
#         [-1.07255425e-03,  1.21434784e-02,  2.00547406e-02,
#           7.84276889e-03,  7.84276889e-03, -1.83921090e-01],
#         [-1.74689080e-02, -1.43161766e-03,  2.08665124e-02,
#          -2.83020532e-02, -2.83020532e-02, -1.43434926e-01],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]]),
#  array([[ 0.00875765,  0.02542512,  0.0275596 ,  0.004497  ,  0.004497  ,
#          -0.25535359],
#         [ 0.00739427,  0.02723657,  0.03152644,  0.00798073,  0.00798073,
#          -0.49913297],
#         [-0.06141345, -0.10478838, -0.03488723, -0.12479779, -0.12479779,
#           1.38316891],
#         [-0.11895192, -0.11831959, -0.09017478, -0.13538129, -0.13538129,
#           0.689301  ],
#         [-0.16164613, -0.16381572, -0.12945801, -0.17214069, -0.17214069,
#           0.72697718]]))

# %%
class LSTM(nn.Module):
    
    def __init__(self, input_dim, hidden_dim, output_dim, num_layers, batch_size, dropout, use_bn):
        super(LSTM, self).__init__()
        self.input_dim = input_dim 
        self.hidden_dim = hidden_dim
        self.output_dim = output_dim
        self.num_layers = num_layers

        self.batch_size = batch_size
        self.dropout = dropout
        self.use_bn = use_bn 
        
        self.lstm = nn.LSTM(self.input_dim, self.hidden_dim, self.num_layers)
        self.hidden = self.init_hidden()
        self.regressor = self.make_regressor()
        
    def init_hidden(self):
        return (torch.zeros(self.num_layers, self.batch_size, self.hidden_dim),
                torch.zeros(self.num_layers, self.batch_size, self.hidden_dim))
    
    def make_regressor(self):
        layers = []
        if self.use_bn:
            layers.append(nn.BatchNorm1d(self.hidden_dim))
        layers.append(nn.Dropout(self.dropout))
        
        layers.append(nn.Linear(self.hidden_dim, self.hidden_dim // 2))
        layers.append(nn.ReLU())
        layers.append(nn.Linear(self.hidden_dim // 2, self.output_dim))
        regressor = nn.Sequential(*layers)
        return regressor
    
    def forward(self, x):
        lstm_out, self.hidden = self.lstm(x, self.hidden)
        y_pred = self.regressor(lstm_out[-1].view(self.batch_size, -1))
        return y_pred

# %%
def metric(y_pred, y_true):
    perc_y_pred = np.exp(y_pred.cpu().detach().numpy())
    perc_y_true = np.exp(y_true.cpu().detach().numpy())
    mae = mean_absolute_error(perc_y_true, perc_y_pred, multioutput='raw_values')
    return mae*100

# %%
def train(model, partition, optimizer, loss_fn, args):
    trainloader = DataLoader(partition['train'], 
                             batch_size=args.batch_size, 
                             shuffle=True, drop_last=True)
    model.train()
    model.zero_grad()
    optimizer.zero_grad()

    train_acc = 0.0
    train_loss = 0.0
    for i, (X, y) in enumerate(trainloader):

        X = X.transpose(0, 1).float().to(args.device)
        y_true = y[:, :, 3].float().to(args.device)
        #print(torch.max(X[:, :, 3]), torch.max(y_true))

        model.zero_grad()
        optimizer.zero_grad()
        model.hidden = [hidden.to(args.device) for hidden in model.init_hidden()]

        y_pred = model(X)
        loss = loss_fn(y_pred.view(-1), y_true.view(-1))
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        train_acc += metric(y_pred, y_true)[0]

    train_loss = train_loss / len(trainloader)
    train_acc = train_acc / len(trainloader)
    return model, train_loss, train_acc

# %%
def validate(model, partition, loss_fn, args):
    valloader = DataLoader(partition['val'], 
                           batch_size=args.batch_size, 
                           shuffle=False, drop_last=True)
    model.eval()
    val_acc = 0.0
    val_loss = 0.0
    with torch.no_grad():
        for i, (X, y) in enumerate(valloader):
            
            X = X.transpose(0, 1).float().to(args.device)
            y_true = y[:, :, 3].float().to(args.device)
            model.hidden = [hidden.to(args.device) for hidden in model.init_hidden()]

            y_pred = model(X)
            loss = loss_fn(y_pred.view(-1), y_true.view(-1))

            val_loss += loss.item()
            val_acc += metric(y_pred, y_true)[0]

    val_loss = val_loss / len(valloader)
    val_acc = val_acc / len(valloader)
    return val_loss, val_acc

# %%
def test(model, partition, args):
    testloader = DataLoader(partition['test'], 
                           batch_size=args.batch_size, 
                           shuffle=False, drop_last=True)
    model.eval()

    test_acc = 0.0
    with torch.no_grad():
        for i, (X, y) in enumerate(testloader):

            X = X.transpose(0, 1).float().to(args.device)
            y_true = y[:, :, 3].float().to(args.device)
            model.hidden = [hidden.to(args.device) for hidden in model.init_hidden()]

            y_pred = model(X)
            test_acc += metric(y_pred, y_true)[0]

    test_acc = test_acc / len(testloader)
    return test_acc

# %%
import time 

def experiment(partition, args):

    model = LSTM(args.input_dim, args.hid_dim, args.y_frames, args.n_layers, args.batch_size, args.dropout, args.use_bn)
    model.to(args.device)
    loss_fn = torch.nn.MSELoss()

    loss_fn = nn.MSELoss()
    if args.optim == 'SGD':
        optimizer = optim.RMSprop(model.parameters(), lr=args.lr, weight_decay=args.l2)
    elif args.optim == 'RMSprop':
        optimizer = optim.RMSprop(model.parameters(), lr=args.lr, weight_decay=args.l2)
    elif args.optim == 'Adam':
        optimizer = optim.Adam(model.parameters(), lr=args.lr, weight_decay=args.l2)
    else:
        raise ValueError('In-valid optimizer choice')
    
    # ===== List for epoch-wise data ====== #
    train_losses = []
    val_losses = []
    train_accs = []
    val_accs = []
    # ===================================== #
        
    for epoch in range(args.epoch):  # loop over the dataset multiple times
        ts = time.time()
        model, train_loss, train_acc = train(model, partition, optimizer, loss_fn, args)
        val_loss, val_acc = validate(model, partition, loss_fn, args)
        te = time.time()
        
        # ====== Add Epoch Data ====== #
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        train_accs.append(train_acc)
        val_accs.append(val_acc)
        # ============================ #
        
        print('Epoch {}, Acc(train/val): {:2.2f}/{:2.2f}, Loss(train/val) {:2.5f}/{:2.5f}. Took {:2.2f} sec'.format(epoch, train_acc, val_acc, train_loss, val_loss, te-ts))
        
    test_acc = test(model, partition, args)    
    
    # ======= Add Result to Dictionary ======= #
    result = {}
    result['train_losses'] = train_losses
    result['val_losses'] = val_losses
    result['train_accs'] = train_accs
    result['val_accs'] = val_accs
    result['train_acc'] = train_acc
    result['val_acc'] = val_acc
    result['test_acc'] = test_acc
    return vars(args), result

# %% [markdown]
# ## Manage Experiment

# %%
import hashlib
import json
from os import listdir
from os.path import isfile, join
import pandas as pd

def save_exp_result(setting, result):
    exp_name = setting['exp_name']
    del setting['epoch']

    hash_key = hashlib.sha1(str(setting).encode()).hexdigest()[:6]
    filename = './results/{}-{}.json'.format(exp_name, hash_key)
    result.update(setting)
    with open(filename, 'w') as f:
        json.dump(result, f)

    
def load_exp_result(exp_name):
    dir_path = './results'
    filenames = [f for f in listdir(dir_path) if isfile(join(dir_path, f)) if '.json' in f]
    list_result = []
    for filename in filenames:
        if exp_name in filename:
            with open(join(dir_path, filename), 'r') as infile:
                results = json.load(infile)
                list_result.append(results)
    df = pd.DataFrame(list_result) # .drop(columns=[])
    return df

# %%
def plot_acc(var1, var2, df):

    fig, ax = plt.subplots(1, 3)
    fig.set_size_inches(15, 6)
    sns.set_style("darkgrid", {"axes.facecolor": ".9"})

    sns.barplot(x=var1, y='train_acc', hue=var2, data=df, ax=ax[0])
    sns.barplot(x=var1, y='val_acc', hue=var2, data=df, ax=ax[1])
    sns.barplot(x=var1, y='test_acc', hue=var2, data=df, ax=ax[2])
    
    ax[0].set_title('Train Accuracy')
    ax[1].set_title('Validation Accuracy')
    ax[2].set_title('Test Accuracy')

    
def plot_loss_variation(var1, var2, df, **kwargs):

    list_v1 = df[var1].unique()
    list_v2 = df[var2].unique()
    list_data = []

    for value1 in list_v1:
        for value2 in list_v2:
            row = df.loc[df[var1]==value1]
            row = row.loc[df[var2]==value2]

            train_losses = list(row.train_losses)[0]
            val_losses = list(row.val_losses)[0]

            for epoch, train_loss in enumerate(train_losses):
                list_data.append({'type':'train', 'loss':train_loss, 'epoch':epoch, var1:value1, var2:value2})
            for epoch, val_loss in enumerate(val_losses):
                list_data.append({'type':'val', 'loss':val_loss, 'epoch':epoch, var1:value1, var2:value2})

    df = pd.DataFrame(list_data)
    g = sns.FacetGrid(df, row=var2, col=var1, hue='type', **kwargs)
    g = g.map(plt.plot, 'epoch', 'loss', marker='.')
    g.add_legend()
    g.fig.suptitle('Train loss vs Val loss')
    plt.subplots_adjust(top=0.89) # 만약 Title이 그래프랑 겹친다면 top 값을 조정해주면 됩니다! 함수 인자로 받으면 그래프마다 조절할 수 있겠죠?


def plot_acc_variation(var1, var2, df, **kwargs):
    list_v1 = df[var1].unique()
    list_v2 = df[var2].unique()
    list_data = []

    for value1 in list_v1:
        for value2 in list_v2:
            row = df.loc[df[var1]==value1]
            row = row.loc[df[var2]==value2]

            train_accs = list(row.train_accs)[0]
            val_accs = list(row.val_accs)[0]
            test_acc = list(row.test_acc)[0]

            for epoch, train_acc in enumerate(train_accs):
                list_data.append({'type':'train', 'Acc':train_acc, 'test_acc':test_acc, 'epoch':epoch, var1:value1, var2:value2})
            for epoch, val_acc in enumerate(val_accs):
                list_data.append({'type':'val', 'Acc':val_acc, 'test_acc':test_acc, 'epoch':epoch, var1:value1, var2:value2})

    df = pd.DataFrame(list_data)
    g = sns.FacetGrid(df, row=var2, col=var1, hue='type', **kwargs)
    g = g.map(plt.plot, 'epoch', 'Acc', marker='.')

    def show_acc(x, y, metric, **kwargs):
        plt.scatter(x, y, alpha=0.3, s=1)
        metric = "Test Acc: {:1.3f}".format(list(metric.values)[0])
        plt.text(0.05, 0.95, metric,  horizontalalignment='left', verticalalignment='center', transform=plt.gca().transAxes, bbox=dict(facecolor='yellow', alpha=0.5, boxstyle="round,pad=0.1"))
    g = g.map(show_acc, 'epoch', 'Acc', 'test_acc')

    g.add_legend()
    g.fig.suptitle('Train Accuracy vs Val Accuracy')
    plt.subplots_adjust(top=0.89)

# %%
parser = argparse.ArgumentParser()
args = parser.parse_args("")

# %%
import time

# %%
# ====== Random Seed Initialization ====== #
seed = 666
np.random.seed(seed)
torch.manual_seed(seed)

args.exp_name = "exp1_lr"
# args.device = "mps" if torch.backends.mps.is_available() else "cpu"
args.device = "cpu"

# ====== Model Capacity ===== #
args.input_dim = 6
args.hid_dim = 64
args.n_layers = 2

# ====== Regularization ======= #
args.l2 = 0.00001
args.dropout = 0.0
args.use_bn = True

# ====== Optimizer & Training ====== #
args.optim = 'Adam' #'RMSprop' #SGD, RMSprop, ADAM...
args.lr = 0.0001
args.epoch = 16


# ====== Experiment Variable ====== #
name_var1 = 'lr'
name_var2 = 'n_layers'
list_var1 = [0.001, 0.0001, 0.00001]
list_var2 = [1,2,3]


# ====== Data Loading ====== #
args.symbol = 'TSLA'
args.batch_size = 16
args.x_frames = 5
args.y_frames = 3

trainset = StockDataset(args.symbol, args.x_frames, args.y_frames, (2018,1,1), (2020,8,31))
valset = StockDataset(args.symbol, args.x_frames, args.y_frames, (2020,9,1), (2020,12,31))
testset = StockDataset(args.symbol, args.x_frames, args.y_frames, (2021,1,1), (2021,12,1))
partition = {'train': trainset, 'val':valset, 'test':testset}

for var1 in list_var1:
    for var2 in list_var2:
        setattr(args, name_var1, var1)
        setattr(args, name_var2, var2)
        print(args)
                
        setting, result = experiment(partition, deepcopy(args))
        save_exp_result(setting, result)
# Out:
# [*********************100%***********************]  1 of 1 completed
# null count :  Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# [*********************100%***********************]  1 of 1 completed
# null count :  Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# [*********************100%***********************]  1 of 1 completed
# null count :  Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Namespace(exp_name='exp1_lr', device='cpu', input_dim=6, hid_dim=64, n_layers=1, l2=1e-05, dropout=0.0, use_bn=True, optim='Adam', lr=0.001, epoch=16, symbol='TSLA', batch_size=16, x_frames=5, y_frames=3)
# Epoch 0, Acc(train/val): 8.98/10.31, Loss(train/val) 0.01136/0.00805. Took 0.73 sec
# Epoch 1, Acc(train/val): 4.51/4.41, Loss(train/val) 0.00465/0.00430. Took 0.75 sec
# Epoch 2, Acc(train/val): 3.59/4.18, Loss(train/val) 0.00386/0.00452. Took 0.76 sec
# Epoch 3, Acc(train/val): 3.45/3.64, Loss(train/val) 0.00374/0.00417. Took 0.72 sec
# Epoch 4, Acc(train/val): 3.31/4.49, Loss(train/val) 0.00384/0.00481. Took 0.71 sec
# Epoch 5, Acc(train/val): 3.30/3.33, Loss(train/val) 0.00367/0.00613. Took 0.71 sec
# Epoch 6, Acc(train/val): 3.21/5.09, Loss(train/val) 0.00382/0.00534. Took 0.73 sec
# Epoch 7, Acc(train/val): 3.19/4.08, Loss(train/val) 0.00368/0.00406. Took 0.73 sec
# Epoch 8, Acc(train/val): 3.25/3.09, Loss(train/val) 0.00366/0.00394. Took 0.72 sec
# Epoch 9, Acc(train/val): 3.15/3.72, Loss(train/val) 0.00350/0.00514. Took 0.78 sec
# Epoch 10, Acc(train/val): 3.11/3.77, Loss(train/val) 0.00369/0.00445. Took 0.72 sec
# Epoch 11, Acc(train/val): 3.12/3.53, Loss(train/val) 0.00355/0.00396. Took 0.74 sec
# Epoch 12, Acc(train/val): 2.88/3.56, Loss(train/val) 0.00340/0.00423. Took 0.76 sec
# Epoch 13, Acc(train/val): 3.14/3.41, Loss(train/val) 0.00357/0.00391. Took 0.74 sec
# Epoch 14, Acc(train/val): 3.16/3.03, Loss(train/val) 0.00360/0.00446. Took 0.75 sec
# Epoch 15, Acc(train/val): 2.96/3.97, Loss(train/val) 0.00348/0.00429. Took 0.76 sec
# Namespace(exp_name='exp1_lr', device='cpu', input_dim=6, hid_dim=64, n_layers=2, l2=1e-05, dropout=0.0, use_bn=True, optim='Adam', lr=0.001, epoch=16, symbol='TSLA', batch_size=16, x_frames=5, y_frames=3)
# Epoch 0, Acc(train/val): 5.14/5.18, Loss(train/val) 0.00595/0.00494. Took 0.76 sec
# Epoch 1, Acc(train/val): 3.85/3.58, Loss(train/val) 0.00425/0.00398. Took 0.75 sec
# Epoch 2, Acc(train/val): 3.67/8.09, Loss(train/val) 0.00404/0.00831. Took 0.75 sec
# Epoch 3, Acc(train/val): 3.51/4.61, Loss(train/val) 0.00392/0.00523. Took 0.75 sec
# Epoch 4, Acc(train/val): 3.22/4.75, Loss(train/val) 0.00360/0.00449. Took 0.74 sec
# Epoch 5, Acc(train/val): 3.16/3.53, Loss(train/val) 0.00362/0.00457. Took 0.75 sec
# Epoch 6, Acc(train/val): 3.24/4.07, Loss(train/val) 0.00373/0.00475. Took 0.76 sec
# Epoch 7, Acc(train/val): 3.25/3.41, Loss(train/val) 0.00363/0.00569. Took 0.75 sec
# Epoch 8, Acc(train/val): 3.11/4.61, Loss(train/val) 0.00354/0.00517. Took 0.77 sec
# Epoch 9, Acc(train/val): 2.91/3.81, Loss(train/val) 0.00346/0.00421. Took 0.76 sec
# Epoch 10, Acc(train/val): 3.20/3.81, Loss(train/val) 0.00366/0.00413. Took 0.77 sec
# Epoch 11, Acc(train/val): 3.15/3.04, Loss(train/val) 0.00358/0.00363. Took 0.75 sec
# Epoch 12, Acc(train/val): 3.08/4.37, Loss(train/val) 0.00353/0.00506. Took 0.76 sec
# Epoch 13, Acc(train/val): 3.06/3.60, Loss(train/val) 0.00351/0.00401. Took 0.76 sec
# Epoch 14, Acc(train/val): 2.93/3.48, Loss(train/val) 0.00344/0.00424. Took 0.76 sec
# Epoch 15, Acc(train/val): 3.06/3.75, Loss(train/val) 0.00348/0.00427. Took 0.75 sec
# Namespace(exp_name='exp1_lr', device='cpu', input_dim=6, hid_dim=64, n_layers=3, l2=1e-05, dropout=0.0, use_bn=True, optim='Adam', lr=0.001, epoch=16, symbol='TSLA', batch_size=16, x_frames=5, y_frames=3)
# Epoch 0, Acc(train/val): 6.17/8.15, Loss(train/val) 0.00810/0.00736. Took 0.79 sec
# Epoch 1, Acc(train/val): 3.62/3.71, Loss(train/val) 0.00449/0.00420. Took 0.78 sec
# Epoch 2, Acc(train/val): 3.22/4.22, Loss(train/val) 0.00374/0.00451. Took 0.78 sec
# Epoch 3, Acc(train/val): 2.92/4.80, Loss(train/val) 0.00343/0.00582. Took 0.79 sec
# Epoch 4, Acc(train/val): 2.92/3.78, Loss(train/val) 0.00349/0.00483. Took 0.78 sec
# Epoch 5, Acc(train/val): 2.94/3.51, Loss(train/val) 0.00337/0.00372. Took 0.81 sec
# Epoch 6, Acc(train/val): 2.82/4.85, Loss(train/val) 0.00338/0.00481. Took 0.80 sec
# Epoch 7, Acc(train/val): 2.83/3.53, Loss(train/val) 0.00335/0.00413. Took 0.80 sec
# Epoch 8, Acc(train/val): 2.89/3.78, Loss(train/val) 0.00338/0.00399. Took 0.80 sec
# Epoch 9, Acc(train/val): 2.85/3.41, Loss(train/val) 0.00334/0.00400. Took 0.81 sec
# Epoch 10, Acc(train/val): 2.81/3.24, Loss(train/val) 0.00330/0.00451. Took 0.81 sec
# Epoch 11, Acc(train/val): 2.76/3.29, Loss(train/val) 0.00329/0.00418. Took 0.79 sec
# Epoch 12, Acc(train/val): 2.75/3.35, Loss(train/val) 0.00329/0.00371. Took 0.79 sec
# Epoch 13, Acc(train/val): 2.77/3.38, Loss(train/val) 0.00332/0.00371. Took 0.81 sec
# Epoch 14, Acc(train/val): 2.79/3.97, Loss(train/val) 0.00326/0.00422. Took 0.81 sec
# Epoch 15, Acc(train/val): 2.82/4.00, Loss(train/val) 0.00330/0.00426. Took 0.84 sec
# Namespace(exp_name='exp1_lr', device='cpu', input_dim=6, hid_dim=64, n_layers=1, l2=1e-05, dropout=0.0, use_bn=True, optim='Adam', lr=0.0001, epoch=16, symbol='TSLA', batch_size=16, x_frames=5, y_frames=3)
# Epoch 0, Acc(train/val): 6.01/10.25, Loss(train/val) 0.01360/0.02152. Took 0.74 sec
# Epoch 1, Acc(train/val): 5.05/6.79, Loss(train/val) 0.00836/0.01252. Took 0.73 sec
# Epoch 2, Acc(train/val): 4.78/4.78, Loss(train/val) 0.00676/0.00643. Took 0.72 sec
# Epoch 3, Acc(train/val): 4.43/4.45, Loss(train/val) 0.00578/0.00552. Took 0.72 sec
# Epoch 4, Acc(train/val): 4.20/4.36, Loss(train/val) 0.00546/0.00493. Took 0.72 sec
# Epoch 5, Acc(train/val): 3.96/4.44, Loss(train/val) 0.00489/0.00455. Took 0.71 sec
# Epoch 6, Acc(train/val): 3.83/4.30, Loss(train/val) 0.00464/0.00489. Took 0.72 sec
# Epoch 7, Acc(train/val): 3.83/4.36, Loss(train/val) 0.00449/0.00456. Took 0.71 sec
# Epoch 8, Acc(train/val): 3.73/4.03, Loss(train/val) 0.00445/0.00455. Took 0.70 sec
# Epoch 9, Acc(train/val): 3.51/3.95, Loss(train/val) 0.00409/0.00448. Took 0.70 sec
# Epoch 10, Acc(train/val): 3.59/3.60, Loss(train/val) 0.00411/0.00430. Took 0.69 sec
# Epoch 11, Acc(train/val): 3.38/3.78, Loss(train/val) 0.00403/0.00415. Took 0.70 sec
# Epoch 12, Acc(train/val): 3.17/3.72, Loss(train/val) 0.00388/0.00411. Took 0.71 sec
# Epoch 13, Acc(train/val): 3.19/3.94, Loss(train/val) 0.00385/0.00428. Took 0.70 sec
# Epoch 14, Acc(train/val): 3.23/3.58, Loss(train/val) 0.00375/0.00400. Took 0.70 sec
# Epoch 15, Acc(train/val): 3.14/3.42, Loss(train/val) 0.00369/0.00392. Took 0.71 sec
# Namespace(exp_name='exp1_lr', device='cpu', input_dim=6, hid_dim=64, n_layers=2, l2=1e-05, dropout=0.0, use_bn=True, optim='Adam', lr=0.0001, epoch=16, symbol='TSLA', batch_size=16, x_frames=5, y_frames=3)
# Epoch 0, Acc(train/val): 8.25/7.86, Loss(train/val) 0.01092/0.00935. Took 0.78 sec
# Epoch 1, Acc(train/val): 5.56/6.11, Loss(train/val) 0.00602/0.00712. Took 0.78 sec
# Epoch 2, Acc(train/val): 4.73/4.60, Loss(train/val) 0.00515/0.00488. Took 0.78 sec
# Epoch 3, Acc(train/val): 4.46/4.59, Loss(train/val) 0.00478/0.00444. Took 0.77 sec
# Epoch 4, Acc(train/val): 4.13/4.12, Loss(train/val) 0.00437/0.00428. Took 0.76 sec
# Epoch 5, Acc(train/val): 3.79/4.09, Loss(train/val) 0.00412/0.00421. Took 0.76 sec
# Epoch 6, Acc(train/val): 3.62/3.60, Loss(train/val) 0.00396/0.00391. Took 0.74 sec
# Epoch 7, Acc(train/val): 3.54/3.61, Loss(train/val) 0.00387/0.00393. Took 0.74 sec
# Epoch 8, Acc(train/val): 3.50/3.95, Loss(train/val) 0.00380/0.00411. Took 0.75 sec
# Epoch 9, Acc(train/val): 3.22/3.58, Loss(train/val) 0.00356/0.00391. Took 0.74 sec
# Epoch 10, Acc(train/val): 3.21/3.69, Loss(train/val) 0.00360/0.00401. Took 0.74 sec
# Epoch 11, Acc(train/val): 3.11/3.40, Loss(train/val) 0.00352/0.00379. Took 0.74 sec
# Epoch 12, Acc(train/val): 3.08/3.29, Loss(train/val) 0.00347/0.00379. Took 0.74 sec
# Epoch 13, Acc(train/val): 3.03/3.40, Loss(train/val) 0.00346/0.00383. Took 0.76 sec
# Epoch 14, Acc(train/val): 3.04/3.33, Loss(train/val) 0.00335/0.00377. Took 0.76 sec
# Epoch 15, Acc(train/val): 2.90/3.33, Loss(train/val) 0.00341/0.00378. Took 0.76 sec
# Namespace(exp_name='exp1_lr', device='cpu', input_dim=6, hid_dim=64, n_layers=3, l2=1e-05, dropout=0.0, use_bn=True, optim='Adam', lr=0.0001, epoch=16, symbol='TSLA', batch_size=16, x_frames=5, y_frames=3)
# Epoch 0, Acc(train/val): 4.62/4.86, Loss(train/val) 0.00524/0.00593. Took 0.80 sec
# Epoch 1, Acc(train/val): 3.80/4.09, Loss(train/val) 0.00429/0.00523. Took 0.80 sec
# Epoch 2, Acc(train/val): 3.52/3.39, Loss(train/val) 0.00393/0.00452. Took 0.80 sec
# Epoch 3, Acc(train/val): 3.26/3.25, Loss(train/val) 0.00372/0.00419. Took 0.79 sec
# Epoch 4, Acc(train/val): 3.13/3.32, Loss(train/val) 0.00357/0.00422. Took 0.78 sec
# Epoch 5, Acc(train/val): 3.06/3.36, Loss(train/val) 0.00350/0.00389. Took 0.78 sec
# Epoch 6, Acc(train/val): 2.94/3.38, Loss(train/val) 0.00342/0.00407. Took 0.78 sec
# Epoch 7, Acc(train/val): 2.94/3.19, Loss(train/val) 0.00340/0.00373. Took 0.78 sec
# Epoch 8, Acc(train/val): 2.84/3.43, Loss(train/val) 0.00338/0.00413. Took 0.78 sec
# Epoch 9, Acc(train/val): 2.89/3.38, Loss(train/val) 0.00333/0.00406. Took 0.78 sec
# Epoch 10, Acc(train/val): 2.83/3.40, Loss(train/val) 0.00334/0.00398. Took 0.79 sec
# Epoch 11, Acc(train/val): 2.83/3.31, Loss(train/val) 0.00337/0.00401. Took 0.79 sec
# Epoch 12, Acc(train/val): 2.82/3.32, Loss(train/val) 0.00324/0.00368. Took 0.79 sec
# Epoch 13, Acc(train/val): 2.81/3.17, Loss(train/val) 0.00331/0.00378. Took 0.80 sec
# Epoch 14, Acc(train/val): 2.84/3.25, Loss(train/val) 0.00329/0.00374. Took 0.81 sec
# Epoch 15, Acc(train/val): 2.83/3.21, Loss(train/val) 0.00325/0.00389. Took 0.80 sec
# Namespace(exp_name='exp1_lr', device='cpu', input_dim=6, hid_dim=64, n_layers=1, l2=1e-05, dropout=0.0, use_bn=True, optim='Adam', lr=1e-05, epoch=16, symbol='TSLA', batch_size=16, x_frames=5, y_frames=3)
# Epoch 0, Acc(train/val): 9.03/10.24, Loss(train/val) 0.09100/0.01791. Took 0.71 sec
# Epoch 1, Acc(train/val): 9.01/9.63, Loss(train/val) 0.07581/0.02868. Took 0.71 sec
# Epoch 2, Acc(train/val): 8.95/8.91, Loss(train/val) 0.06307/0.03852. Took 0.70 sec
# Epoch 3, Acc(train/val): 8.49/8.78, Loss(train/val) 0.05283/0.03215. Took 0.70 sec
# Epoch 4, Acc(train/val): 8.38/8.66, Loss(train/val) 0.04383/0.02895. Took 0.70 sec
# Epoch 5, Acc(train/val): 8.27/8.68, Loss(train/val) 0.03606/0.02470. Took 0.70 sec
# Epoch 6, Acc(train/val): 8.05/8.52, Loss(train/val) 0.03066/0.02263. Took 0.70 sec
# Epoch 7, Acc(train/val): 7.75/8.58, Loss(train/val) 0.02645/0.02110. Took 0.71 sec
# Epoch 8, Acc(train/val): 7.96/8.41, Loss(train/val) 0.02312/0.01857. Took 0.71 sec
# Epoch 9, Acc(train/val): 7.57/8.36, Loss(train/val) 0.02030/0.01705. Took 0.71 sec
# Epoch 10, Acc(train/val): 7.38/8.23, Loss(train/val) 0.01798/0.01629. Took 0.72 sec
# Epoch 11, Acc(train/val): 7.62/8.14, Loss(train/val) 0.01671/0.01519. Took 0.72 sec
# Epoch 12, Acc(train/val): 7.29/8.07, Loss(train/val) 0.01538/0.01473. Took 0.71 sec
# Epoch 13, Acc(train/val): 7.19/8.00, Loss(train/val) 0.01419/0.01456. Took 0.70 sec
# Epoch 14, Acc(train/val): 7.18/7.88, Loss(train/val) 0.01357/0.01420. Took 0.69 sec
# Epoch 15, Acc(train/val): 7.07/7.74, Loss(train/val) 0.01293/0.01309. Took 0.69 sec
# Namespace(exp_name='exp1_lr', device='cpu', input_dim=6, hid_dim=64, n_layers=2, l2=1e-05, dropout=0.0, use_bn=True, optim='Adam', lr=1e-05, epoch=16, symbol='TSLA', batch_size=16, x_frames=5, y_frames=3)
# Epoch 0, Acc(train/val): 5.64/3.60, Loss(train/val) 0.02129/0.00951. Took 0.74 sec
# Epoch 1, Acc(train/val): 4.37/3.68, Loss(train/val) 0.01661/0.00964. Took 0.75 sec
# Epoch 2, Acc(train/val): 3.92/3.15, Loss(train/val) 0.01382/0.01028. Took 0.74 sec
# Epoch 3, Acc(train/val): 3.60/3.22, Loss(train/val) 0.01159/0.01019. Took 0.74 sec
# Epoch 4, Acc(train/val): 3.48/3.20, Loss(train/val) 0.01024/0.00893. Took 0.75 sec
# Epoch 5, Acc(train/val): 3.41/3.20, Loss(train/val) 0.00914/0.00852. Took 0.76 sec
# Epoch 6, Acc(train/val): 3.34/3.20, Loss(train/val) 0.00821/0.00819. Took 0.76 sec
# Epoch 7, Acc(train/val): 3.28/3.14, Loss(train/val) 0.00782/0.00779. Took 0.76 sec
# Epoch 8, Acc(train/val): 3.23/3.12, Loss(train/val) 0.00740/0.00755. Took 0.77 sec
# Epoch 9, Acc(train/val): 3.22/3.14, Loss(train/val) 0.00699/0.00730. Took 0.78 sec
# Epoch 10, Acc(train/val): 3.23/3.16, Loss(train/val) 0.00683/0.00700. Took 0.77 sec
# Epoch 11, Acc(train/val): 3.11/3.16, Loss(train/val) 0.00679/0.00698. Took 0.74 sec
# Epoch 12, Acc(train/val): 3.11/3.17, Loss(train/val) 0.00632/0.00691. Took 0.74 sec
# Epoch 13, Acc(train/val): 3.12/3.16, Loss(train/val) 0.00637/0.00668. Took 0.74 sec
# Epoch 14, Acc(train/val): 3.09/3.18, Loss(train/val) 0.00628/0.00672. Took 0.74 sec
# Epoch 15, Acc(train/val): 3.09/3.17, Loss(train/val) 0.00627/0.00665. Took 0.74 sec
# Namespace(exp_name='exp1_lr', device='cpu', input_dim=6, hid_dim=64, n_layers=3, l2=1e-05, dropout=0.0, use_bn=True, optim='Adam', lr=1e-05, epoch=16, symbol='TSLA', batch_size=16, x_frames=5, y_frames=3)
# Epoch 0, Acc(train/val): 8.28/11.04, Loss(train/val) 0.00858/0.00889. Took 0.79 sec
# Epoch 1, Acc(train/val): 8.00/10.61, Loss(train/val) 0.00744/0.00855. Took 0.80 sec
# Epoch 2, Acc(train/val): 7.86/8.11, Loss(train/val) 0.00683/0.00694. Took 0.80 sec
# Epoch 3, Acc(train/val): 7.40/7.66, Loss(train/val) 0.00632/0.00658. Took 0.80 sec
# Epoch 4, Acc(train/val): 7.24/7.57, Loss(train/val) 0.00614/0.00659. Took 0.80 sec
# Epoch 5, Acc(train/val): 7.10/7.19, Loss(train/val) 0.00599/0.00623. Took 0.80 sec
# Epoch 6, Acc(train/val): 6.80/7.17, Loss(train/val) 0.00577/0.00625. Took 0.80 sec
# Epoch 7, Acc(train/val): 6.67/6.78, Loss(train/val) 0.00565/0.00598. Took 0.79 sec
# Epoch 8, Acc(train/val): 6.47/6.82, Loss(train/val) 0.00546/0.00601. Took 0.78 sec
# Epoch 9, Acc(train/val): 6.30/6.78, Loss(train/val) 0.00532/0.00589. Took 0.79 sec
# Epoch 10, Acc(train/val): 6.32/6.62, Loss(train/val) 0.00529/0.00576. Took 0.83 sec
# Epoch 11, Acc(train/val): 6.18/6.28, Loss(train/val) 0.00524/0.00552. Took 0.81 sec
# Epoch 12, Acc(train/val): 6.06/6.33, Loss(train/val) 0.00512/0.00553. Took 0.82 sec
# Epoch 13, Acc(train/val): 5.87/6.02, Loss(train/val) 0.00499/0.00534. Took 0.80 sec
# Epoch 14, Acc(train/val): 5.84/5.87, Loss(train/val) 0.00489/0.00529. Took 0.86 sec
# Epoch 15, Acc(train/val): 5.70/6.07, Loss(train/val) 0.00480/0.00530. Took 0.82 sec

# %%
var1 = 'lr'
var2 = 'n_layers'
df = load_exp_result('exp1')

plot_acc(var1, var2, df)
plot_loss_variation(var1, var2, df, sharey=False) #sharey를 True로 하면 모둔 subplot의 y축의 스케일이 같아집니다.
plot_acc_variation(var1, var2, df, margin_titles=True, sharey=True)
